# %% [markdown]
# ## Preprocess Dataset Notebook

# %%
#Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import mne
from scipy.stats import mannwhitneyu
import os

os.chdir("/Users/diego/Desktop/Master Neuro/M2/Internship_Valencia/multimodal-exist/")

# %%
#Load Data
df = pd.read_parquet("./data/processed/train.parquet")
df.head()
# Out:
#        id lang                                               text  \
# 0  110887   es  A VECES QUISIERAIR/ALZUMBA www.facebook.com/Oi...
# 1  110466   es  Se necesita cuidadora para adulto mayor.... fo...
# 2  111269   es  tomboy como son el anime y manga pre to tomboy...
# 3  110593   es  HOY QUIERO FELICITAR A TODAS LAS MUJERES DE ES...
# 4  110946   es           DUCHATE GUARRA GRACIAS memegenerator.es
#
#     image_file  split                                             ET_raw  \
# 0  110887.jpeg  Train  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 1  110466.jpeg  Train  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 2  111269.jpeg  Train  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 3  110593.jpeg  Train  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 4  110946.jpeg  Train  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
#
#                                               HR_raw  \
# 0  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 1  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 2  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 3  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
# 4  {'EN1': None, 'EN2': None, 'EN3': None, 'EN4':...
#
#                                              EEG_raw  task21_hard  \
# 0  {'EN1': None, 'EN2': None, 'EN3': None, 'EN5':...          1.0
# 1  {'EN1': None, 'EN2': None, 'EN3': None, 'EN5':...          NaN
# 2  {'EN1': None, 'EN2': None, 'EN3': None, 'EN5':...          1.0
# 3  {'EN1': None, 'EN2': None, 'EN3': None, 'EN5':...          0.0
# 4  {'EN1': None, 'EN2': None, 'EN3': None, 'EN5':...          1.0
#
#    task21_valid_hard  task21_soft  task22_hard  task22_valid_hard  \
# 0               True     1.000000          1.0               True
# 1              False     0.500000          1.0               True
# 2               True     0.833333          1.0               True
# 3               True     0.166667          NaN              False
# 4               True     0.666667          1.0               True
#
#    task22_soft                                        task23_hard  \
# 0     0.833333  {'IDEOLOGICAL-INEQUALITY': 0, 'MISOGYNY-NON-SE...
# 1     1.000000  {'IDEOLOGICAL-INEQUALITY': 0, 'MISOGYNY-NON-SE...
# 2     1.000000  {'IDEOLOGICAL-INEQUALITY': 0, 'MISOGYNY-NON-SE...
# 3     0.000000  {'IDEOLOGICAL-INEQUALITY': 0, 'MISOGYNY-NON-SE...
# 4     1.000000  {'IDEOLOGICAL-INEQUALITY': 0, 'MISOGYNY-NON-SE...
#
#    task23_valid_hard                                        task23_soft  \
# 0               True  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
# 1               True  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
# 2               True  {'IDEOLOGICAL-INEQUALITY': 0.0, 'MISOGYNY-NON-...
# 3              False  {'IDEOLOGICAL-INEQUALITY': 0.0, 'MISOGYNY-NON-...
# 4               True  {'IDEOLOGICAL-INEQUALITY': 0.0, 'MISOGYNY-NON-...
#
#    task23_num_hard_labels
# 0                       2
# 1                       2
# 2                       1
# 3                       0
# 4                       1
