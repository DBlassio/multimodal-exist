# %% [markdown]
# ## Exploratory Data Analysis (EXIST 2026 Dataset)
#
# This notebook explores the EXIST 2026 Dataset that focuses on multimedia formats: images (memes) and videos (TikToks). The main focus of the Exist Task is sexism identification.

# %%
#Libraries
import json
from pathlib import Path
from collections import Counter
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os

os.chdir("C:/Users/diego/Desktop/Master Neuro/M2/Internship_Valencia/multimodal-exist")

# %%
#Path to the data
DATA_DIR = os.path.join("data", "memes", "training")
IMAGES_DIR = os.path.join(DATA_DIR, "memes")

# %%
#Load the data 
with open(os.path.join(DATA_DIR, "EXIST2026_training.json"), "r", encoding="utf-8") as f:
    raw_data = json.load(f)

# Convert the raw data into a list of records
records = []
for key, item in raw_data.items():
    row = item.copy()
    records.append(row)

#Dataframe creation
df = pd.DataFrame(records)
df.head()
# Out:
#   id_EXIST lang                                               text  \
# 0   110887   es  A VECES QUISIERAIR/ALZUMBA www.facebook.com/Oi...
# 1   110466   es  Se necesita cuidadora para adulto mayor.... fo...
# 2   111269   es  tomboy como son el anime y manga pre to tomboy...
# 3   110593   es  HOY QUIERO FELICITAR A TODAS LAS MUJERES DE ES...
# 4   110946   es           DUCHATE GUARRA GRACIAS memegenerator.es
#
#           meme         path_memes  number_annotators  \
# 0  110887.jpeg  memes/110887.jpeg                  6
# 1  110466.jpeg  memes/110466.jpeg                  6
# 2  111269.jpeg  memes/111269.jpeg                  6
# 3  110593.jpeg  memes/110593.jpeg                  6
# 4  110946.jpeg  memes/110946.jpeg                  6
#
#                                           annotators   gender_annotators  \
# 0  [Annotator_193, Annotator_194, Annotator_195, ...  [F, F, F, M, M, M]
# 1  [Annotator_103, Annotator_104, Annotator_105, ...  [F, F, F, M, M, M]
# 2  [Annotator_277, Annotator_278, Annotator_279, ...  [F, F, F, M, M, M]
# 3  [Annotator_127, Annotator_128, Annotator_129, ...  [F, F, F, M, M, M]
# 4  [Annotator_211, Annotator_212, Annotator_213, ...  [F, F, F, M, M, M]
#
#                            age_annotators  \
# 0  [18-22, 23-45, 46+, 46+, 18-22, 23-45]
# 1  [18-22, 23-45, 46+, 46+, 18-22, 23-45]
# 2  [18-22, 23-45, 46+, 46+, 18-22, 23-45]
# 3  [18-22, 23-45, 46+, 46+, 18-22, 23-45]
# 4  [18-22, 23-45, 46+, 46+, 18-22, 23-45]
#
#                               ethnicities_annotators  \
# 0  [White or Caucasian, Multiracial, White or Cau...
# 1  [White or Caucasian, White or Caucasian, Hispa...
# 2  [White or Caucasian, Hispano or Latino, other,...
# 3  [White or Caucasian, Hispano or Latino, White ...
# 4  [White or Caucasian, Hispano or Latino, White ...
#
#                              study_levels_annotators  \
# 0  [High school degree or equivalent, Master’s de...
# 1  [Bachelor’s degree, High school degree or equi...
# 2  [Bachelor’s degree, Master’s degree, High scho...
# 3  [High school degree or equivalent, Master’s de...
# 4  [Bachelor’s degree, Bachelor’s degree, Bachelo...
#
#                                 countries_annotators  \
# 0  [Sweden, United States, Spain, Portugal, Spain...
# 1  [Spain, Portugal, Spain, Canada, United States...
# 2      [Spain, Spain, Spain, Italy, Spain, Portugal]
# 3  [Poland, Portugal, Spain, United Kingdom, Mexi...
# 4   [Portugal, Chile, Italy, Portugal, Spain, Chile]
#
#                                            sensorial  \
# 0  {'users': ['ES1', 'ES2', 'ES3'], 'modalities':...
# 1  {'users': ['ES1', 'ES2', 'ES3'], 'modalities':...
# 2  {'users': ['ES1', 'ES2', 'ES3'], 'modalities':...
# 3  {'users': ['ES1', 'ES3'], 'modalities': {'ET':...
# 4  {'users': ['ES1', 'ES2', 'ES3', 'ES4'], 'modal...
#
#                    labels_task2_1  \
# 0  [YES, YES, YES, YES, YES, YES]
# 1     [YES, NO, YES, YES, NO, NO]
# 2   [YES, YES, YES, YES, YES, NO]
# 3       [NO, YES, NO, NO, NO, NO]
# 4    [YES, YES, YES, YES, NO, NO]
#
#                                       labels_task2_2  \
# 0  [JUDGEMENTAL, DIRECT, DIRECT, DIRECT, DIRECT, ...
# 1                  [DIRECT, -, DIRECT, DIRECT, -, -]
# 2        [DIRECT, DIRECT, DIRECT, DIRECT, DIRECT, -]
# 3                       [-, JUDGEMENTAL, -, -, -, -]
# 4             [DIRECT, DIRECT, DIRECT, DIRECT, -, -]
#
#                                       labels_task2_3          split
# 0  [[IDEOLOGICAL-INEQUALITY, OBJECTIFICATION], [M...  TRAIN-MEME_ES
# 1  [[STEREOTYPING-DOMINANCE], [-], [STEREOTYPING-...  TRAIN-MEME_ES
# 2  [[OBJECTIFICATION, SEXUAL-VIOLENCE], [OBJECTIF...  TRAIN-MEME_ES
# 3  [[-], [STEREOTYPING-DOMINANCE, OBJECTIFICATION...  TRAIN-MEME_ES
# 4  [[OBJECTIFICATION], [SEXUAL-VIOLENCE], [OBJECT...  TRAIN-MEME_ES

# %%
#Helpers

#Get the raw modality data for a given modality
def get_modality_raw(sensorial, modality):
    if not isinstance(sensorial, dict):
        return None
    return sensorial.get("modalities", {}).get(modality, {}).get("by_user", None)

# Calculate the soft labels for Task 2.1
def soft_task21(labels):
    valid = [x for x in labels if x != "UNKNOWN"]
    total = len(valid)
    if total == 0:
        return {"YES": np.nan, "NO": np.nan}
    
    counts = Counter(valid)
    return {
        "YES": counts.get("YES", 0) / total,
        "NO": counts.get("NO", 0) / total}

# Calculate the hard label for Task 2.1 based argmax 
def hard_task21(labels, threshold=3):
    valid = [x for x in labels if x != "UNKNOWN"]
    total = len(valid)
    if total == 0:
        return {"YES": np.nan, "NO": np.nan}
    
    counts = Counter(valid)

    if counts.get("YES", 0) >= counts.get("NO", 0):
        return "YES", True
    else:
        return "NO", True
    
# Calculate the soft labels for Task 2.2
def soft_task22(labels):
    valid = [x for x in labels if x not in {"UNKNOWN", "-"}]
    total = len(valid)
    if total == 0:
        return {"DIRECT": np.nan, "JUDGEMENTAL": np.nan}
    
    counts = Counter(valid)
    return {
        "DIRECT": counts.get("DIRECT", 0) / total,
        "JUDGEMENTAL": counts.get("JUDGEMENTAL", 0) / total}

# Calculate the hard label for Task 2.2 based on an official threshold
def hard_task22(labels, threshold=2):
    valid = [x for x in labels if x not in {"UNKNOWN", "-"}]
    total = len(valid)
    if total == 0:
        return "-", False
    
    counts = Counter(valid)

    if counts.get("DIRECT", 0) >= counts.get("JUDGEMENTAL", 0):
            return "DIRECT", True
    else:
            return "JUDGEMENTAL", True

# Calculate the soft labels for Task 2.3 (5 classes)
TASK23_CLASSES = ["IDEOLOGICAL-INEQUALITY","STEREOTYPING-DOMINANCE","OBJECTIFICATION","SEXUAL-VIOLENCE","MISOGYNY-NON-SEXUAL-VIOLENCE"]

def soft_task23(labels_task23):
    valid_annotators = []
    for ann_labels in labels_task23:
        if not isinstance(ann_labels, list):
            continue
        filtered = [x for x in ann_labels if x not in {"UNKNOWN", "-"}]
        valid_annotators.append(filtered)
    
    total = len(valid_annotators)
    if total == 0:
        return {c: np.nan for c in TASK23_CLASSES}
    
    counts = Counter()
    for ann_labels in valid_annotators:
        for c in ann_labels:
            counts[c] += 1
    
    return {c: counts.get(c, 0) / total for c in TASK23_CLASSES}

#Calculate the hard labels for Task 2.3 based on an official threshold
def hard_task23(labels_task23, threshold=1):
    valid_annotators = []
    for ann_labels in labels_task23:
        if not isinstance(ann_labels, list):
            continue
        filtered = [x for x in ann_labels if x not in {"UNKNOWN", "-"}]
        valid_annotators.append(filtered)
    
    if len(valid_annotators) == 0:
        return [], False
    
    counts = Counter()
    for ann_labels in valid_annotators:
        for c in ann_labels:
            counts[c] += 1
    
    hard_labels = {c: int(counts.get(c, 0) > threshold) for c in TASK23_CLASSES}
    
    return hard_labels, any(hard_labels.values())

# %%
rows = []

for _, row in df.iterrows():
    task21_soft = soft_task21(row["labels_task2_1"])
    task21_hard, task21_valid = hard_task21(row["labels_task2_1"])
    
    task22_soft = soft_task22(row["labels_task2_2"])
    task22_hard, task22_valid = hard_task22(row["labels_task2_2"])
    
    task23_soft = soft_task23(row["labels_task2_3"])
    task23_hard, task23_valid = hard_task23(row["labels_task2_3"])
    
    new_row = {
        "id": row["id_EXIST"],
        "lang": row["lang"],
        "text": row["text"],
        "image_file": row["meme"],
        "split": "Train",
        
        "ET_raw": get_modality_raw(row["sensorial"], "ET"),
        "HR_raw": get_modality_raw(row["sensorial"], "HR"),
        "EEG_raw": get_modality_raw(row["sensorial"], "EEG"),
        
        "task21_hard": task21_hard,
        "task21_valid_hard": task21_valid,
        "task21_soft": task21_soft,
        
        "task22_hard": task22_hard,
        "task22_valid_hard": task22_valid,
        "task22_soft": task22_soft,
        
        "task23_hard": task23_hard,
        "task23_valid_hard": task23_valid,
        "task23_soft": task23_soft,
    }
    
    rows.append(new_row)

train_base = pd.DataFrame(rows)
train_base.head(5)
# Out:
#        id lang                                               text  \
# 0  110887   es  A VECES QUISIERAIR/ALZUMBA www.facebook.com/Oi...
# 1  110466   es  Se necesita cuidadora para adulto mayor.... fo...
# 2  111269   es  tomboy como son el anime y manga pre to tomboy...
# 3  110593   es  HOY QUIERO FELICITAR A TODAS LAS MUJERES DE ES...
# 4  110946   es           DUCHATE GUARRA GRACIAS memegenerator.es
#
#     image_file  split                                             ET_raw  \
# 0  110887.jpeg  Train  {'ES2': {'reaction_time': 16708.0, '3d_eye_sta...
# 1  110466.jpeg  Train  {'ES1': {'reaction_time': 23014.0, '3d_eye_sta...
# 2  111269.jpeg  Train  {'ES2': {'reaction_time': 9692.0, '3d_eye_stat...
# 3  110593.jpeg  Train  {'ES3': {'reaction_time': 10421.0, '3d_eye_sta...
# 4  110946.jpeg  Train  {'ES2': {'reaction_time': 5174.0, '3d_eye_stat...
#
#                                               HR_raw  \
# 0  {'ES2': {'garmin_hr_mean': 59.7647, 'garmin_hr...
# 1  {'ES1': {'garmin_hr_mean': 59.3913, 'garmin_hr...
# 2  {'ES2': {'garmin_hr_mean': 60.2, 'garmin_hr_st...
# 3  {'ES3': {'garmin_hr_mean': 68.4545, 'garmin_hr...
# 4  {'ES2': {'garmin_hr_mean': 68.3333, 'garmin_hr...
#
#                                              EEG_raw task21_hard  \
# 0  {'ES1': {'EXG_Channel_0_Delta_power': -0.5379,...         YES
# 1  {'ES1': {'EXG_Channel_0_Delta_power': 0.4666, ...         YES
# 2  {'ES1': {'EXG_Channel_0_Delta_power': 0.6395, ...         YES
# 3  {'ES1': {'EXG_Channel_0_Delta_power': 0.6614, ...          NO
# 4  {'ES1': {'EXG_Channel_0_Delta_power': 0.0069, ...         YES
#
#    task21_valid_hard                                        task21_soft  \
# 0               True                            {'YES': 1.0, 'NO': 0.0}
# 1               True                            {'YES': 0.5, 'NO': 0.5}
# 2               True  {'YES': 0.8333333333333334, 'NO': 0.1666666666...
# 3               True  {'YES': 0.16666666666666666, 'NO': 0.833333333...
# 4               True  {'YES': 0.6666666666666666, 'NO': 0.3333333333...
#
#    task22_hard  task22_valid_hard  \
# 0       DIRECT               True
# 1       DIRECT               True
# 2       DIRECT               True
# 3  JUDGEMENTAL               True
# 4       DIRECT               True
#
#                                          task22_soft  \
# 0  {'DIRECT': 0.8333333333333334, 'JUDGEMENTAL': ...
# 1                {'DIRECT': 1.0, 'JUDGEMENTAL': 0.0}
# 2                {'DIRECT': 1.0, 'JUDGEMENTAL': 0.0}
# 3                {'DIRECT': 0.0, 'JUDGEMENTAL': 1.0}
# 4                {'DIRECT': 1.0, 'JUDGEMENTAL': 0.0}
#
#                                          task23_hard  task23_valid_hard  \
# 0  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...               True
# 1  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...               True
# 2  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...               True
# 3  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...              False
# 4  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...               True
#
#                                          task23_soft
# 0  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
# 1  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
# 2  {'IDEOLOGICAL-INEQUALITY': 0.0, 'STEREOTYPING-...
# 3  {'IDEOLOGICAL-INEQUALITY': 0.0, 'STEREOTYPING-...
# 4  {'IDEOLOGICAL-INEQUALITY': 0.0, 'STEREOTYPING-...

# %% [markdown]
# ## 2.1 Binary Classification (Sexism)

# %%
# We can directly map the hard labels to binary values 
# 2.1 is a binary classification task, so we can convert the "YES"/"NO" labels to 1/0
# and soft labels to the probability of "YES"

task21_hard_map = {"YES": 1, "NO": 0}
train_base["task21_hard"] = train_base["task21_hard"].map(task21_hard_map)
train_base["task21_soft"] = train_base["task21_soft"].apply(lambda x: x.get("YES"))
train_base.head(2)
# Out:
#        id lang                                               text  \
# 0  110887   es  A VECES QUISIERAIR/ALZUMBA www.facebook.com/Oi...
# 1  110466   es  Se necesita cuidadora para adulto mayor.... fo...
#
#     image_file  split                                             ET_raw  \
# 0  110887.jpeg  Train  {'ES2': {'reaction_time': 16708.0, '3d_eye_sta...
# 1  110466.jpeg  Train  {'ES1': {'reaction_time': 23014.0, '3d_eye_sta...
#
#                                               HR_raw  \
# 0  {'ES2': {'garmin_hr_mean': 59.7647, 'garmin_hr...
# 1  {'ES1': {'garmin_hr_mean': 59.3913, 'garmin_hr...
#
#                                              EEG_raw  task21_hard  \
# 0  {'ES1': {'EXG_Channel_0_Delta_power': -0.5379,...            1
# 1  {'ES1': {'EXG_Channel_0_Delta_power': 0.4666, ...            1
#
#    task21_valid_hard  task21_soft task22_hard  task22_valid_hard  \
# 0               True          1.0      DIRECT               True
# 1               True          0.5      DIRECT               True
#
#                                          task22_soft  \
# 0  {'DIRECT': 0.8333333333333334, 'JUDGEMENTAL': ...
# 1                {'DIRECT': 1.0, 'JUDGEMENTAL': 0.0}
#
#                                          task23_hard  task23_valid_hard  \
# 0  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...               True
# 1  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...               True
#
#                                          task23_soft
# 0  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
# 1  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...

# %% [markdown]
# ## 2.2 Binary Classification (Intention Detection)

# %%
# We can directly map the hard labels to binary values 
# 2.2 is a binary classification task, so we can convert the "DIRECT"/"JUDGEMENTAL" labels to 1/0
# and soft labels to the probability of "DIRECT"

task22_hard_map = {"DIRECT": 1, "JUDGEMENTAL": 0}
train_base["task22_hard"] = train_base["task22_hard"].map(task22_hard_map)
train_base["task22_soft"] = train_base["task22_soft"].apply(lambda x: x.get("DIRECT"))
train_base.head(2)
# Out:
#        id lang                                               text  \
# 0  110887   es  A VECES QUISIERAIR/ALZUMBA www.facebook.com/Oi...
# 1  110466   es  Se necesita cuidadora para adulto mayor.... fo...
#
#     image_file  split                                             ET_raw  \
# 0  110887.jpeg  Train  {'ES2': {'reaction_time': 16708.0, '3d_eye_sta...
# 1  110466.jpeg  Train  {'ES1': {'reaction_time': 23014.0, '3d_eye_sta...
#
#                                               HR_raw  \
# 0  {'ES2': {'garmin_hr_mean': 59.7647, 'garmin_hr...
# 1  {'ES1': {'garmin_hr_mean': 59.3913, 'garmin_hr...
#
#                                              EEG_raw  task21_hard  \
# 0  {'ES1': {'EXG_Channel_0_Delta_power': -0.5379,...            1
# 1  {'ES1': {'EXG_Channel_0_Delta_power': 0.4666, ...            1
#
#    task21_valid_hard  task21_soft  task22_hard  task22_valid_hard  \
# 0               True          1.0          1.0               True
# 1               True          0.5          1.0               True
#
#    task22_soft                                        task23_hard  \
# 0     0.833333  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...
# 1     1.000000  {'IDEOLOGICAL-INEQUALITY': 0, 'STEREOTYPING-DO...
#
#    task23_valid_hard                                        task23_soft
# 0               True  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
# 1               True  {'IDEOLOGICAL-INEQUALITY': 0.16666666666666666...
